# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px 
import seaborn as sns 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from math import radians, cos, sin, asin, sqrt
def calculate_distance(lat1, lat2, lon1, lon2):
	# The math module contains a function named
	# radians which converts from degrees to radians.
	lon1 = radians(lon1)
	lon2 = radians(lon2)
	lat1 = radians(lat1)
	lat2 = radians(lat2)
	
	# Haversine formula
	dlon = lon2 - lon1
	dlat = lat2 - lat1
	a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2

	c = 2 * asin(sqrt(a))
	
	# Radius of earth in kilometers. Use 3956 for miles
	r = 6371
	
	# calculate the result
	return(c * r)

# %%
data = pd.read_csv('../input/uber-fares-dataset/uber.csv')

# %%
data.columns

# %%
data.info()

# %%
#type casting : 
data

# %%
#fix the weirdness of ccoordinate
data.describe()
data.dtypes
print('Null Values :')
data.isnull().sum()

# %%
data = data.drop_duplicates(keep='first')
data

# %%
data_filtered = data.loc[(((data['pickup_longitude'] <= 180) & (data['pickup_longitude'] >= -180)) & (data['dropoff_longitude'] <= 180)) & (data['dropoff_longitude'] >= -180)]
data_filtered = data_filtered.loc[(((data_filtered['pickup_latitude'] <= 90) & (data_filtered['pickup_latitude'] >= -90)) & (data_filtered['dropoff_latitude'] <= 180)) & (data_filtered['dropoff_latitude'] >= -90)]
data_filtered

# %% [markdown]
# ## MARKDOWN

# %%
example = data_filtered.iloc[:10]
def print_(data) : 
    print(data.shape)
example.apply(lambda x : print_(example))

# %%
def remove_outliers(data:pd.DataFrame,exeption_col = ['Unnamed: 0','key','pickup_datetime','pickup_longitude','pickup_latitude',
                                                    'dropoff_longitude','dropoff_latitude'])->pd.DataFrame : 
    """
    a function to remove outlier within pandas dataframe with iqr method
    Args : 
    data : pandas dataframe
    Return
    pd.DataFrame(cleaned)
    """
    for col in data.select_dtypes(exclude='object').columns : 
        if col not in exeption_col : 
#creating function to remove outlier by interquartil range 
            q1_ = np.quantile(data[col],0.25)
            q3_ = np.quantile(data[col],0.75)
            iqr_ = q3_ - q1_
            # Create the lower & upper bound 
            lower_ = q1_ - 1.5*iqr_
            upper_ = q3_ + 1.5*iqr_
            #implement using joblib 
            for val in data[col].values : 
                if lower_ <= val <= upper_:
                    # Do nothing when the column value inside the safe boundary
                    continue
                else:
                    #drop the values
                    filter_drop = data[data[col] == val].index
                    data.drop(filter_drop,axis=0,inplace=True)
                    data.reindex()
        else : 
            continue
        
    print('Done')
    return data

# %%
data_removed_outliers = remove_outliers(data=data_filtered)

# %%
data_removed_outliers.to_csv('data_removed_outliers.csv',index=False)

# %%
#create reading checkpoint to avoid time consuming process of removing outlier 
data_removed_outliers = pd.read_csv('data_removed_outliers.csv')

# %%
data_removed_outliers.shape

# %%
lat1, lat2, lon1, lon2

# %%
data_removed_outliers.columns

# %%
data_removed_outliers['distance'] = data_removed_outliers.apply(lambda x : calculate_distance(x['pickup_latitude'], x['dropoff_latitude'], 
                                                                                  x['pickup_longitude'],x['dropoff_longitude']),axis=1)
#     lat1=data_removed_outliers['pickup_latitude'],
#                                                       lat2=data_removed_outliers['dropoff_latitude'],
#                                                       lon1=data_removed_outliers['pickup_longitude'],
#                                                       lon2=data_removed_outliers['dropoff_longitude'])

# %%
data_removed_outliers

# %%
data_removed_outliers['pickup_datetime'] = pd.to_datetime(data_removed_outliers['pickup_datetime'], infer_datetime_format=True)
data_removed_outliers['pickup_datetime_year'] = data_removed_outliers['pickup_datetime'].dt.year
data_removed_outliers['pickup_datetime_dayofmonth'] = data_removed_outliers['pickup_datetime'].dt.day
data_removed_outliers['pickup_datetime_dayofweek'] = data_removed_outliers['pickup_datetime'].dt.dayofweek
data_removed_outliers['pickup_datetime_hour'] = data_removed_outliers['pickup_datetime'].dt.hour
data_removed_outliers['pickup_datetime_month_name'] = data_removed_outliers['pickup_datetime'].dt.month_name()
data_removed_outliers

# %%
data_removed_outliers.to_csv('ready_for_EDA.csv',index=False)

# %%
import bamboolib as bam 
bam.enable()
# Out:
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'

# %%
data_eda = pd.read_csv('ready_for_EDA.csv')

# %%
data_eda['pickup_datetime'] = pd.to_datetime(data_eda['pickup_datetime'], infer_datetime_format=True)
data_eda['pickup_datetime_weekday_name'] = data_eda['pickup_datetime'].dt.day_name()
data_eda
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         44470845    2011-02-12 02:27:09.0000006          4.9
# ...            ...                            ...          ...
# 162264     3189201  2014-01-31 14:42:00.000000181         12.0
# 162265    42598914   2012-10-28 10:49:00.00000053          3.0
# 162266    16382965    2014-03-14 01:09:00.0000008          7.5
# 162267    20259894    2015-05-20 14:56:25.0000004         14.5
# 162268    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1       2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2       2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3       2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4       2011-02-12 02:27:09+00:00        -73.969019        40.755910
# ...                           ...               ...              ...
# 162264  2014-01-31 14:42:00+00:00        -73.983070        40.760770
# 162265  2012-10-28 10:49:00+00:00        -73.987042        40.739367
# 162266  2014-03-14 01:09:00+00:00        -73.984722        40.736837
# 162267  2015-05-20 14:56:25+00:00        -73.997124        40.725452
# 162268  2010-05-15 04:08:00+00:00        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count  distance  \
# 0              -73.999512         40.723217                1  1.683323
# 1              -73.994710         40.750325                1  2.457590
# 2              -73.962565         40.772647                1  5.036377
# 3              -73.965316         40.803349                3  1.661683
# 4              -73.969019         40.755910                1  0.000000
# ...                   ...               ...              ...       ...
# 162264         -73.972972         40.754177                1  1.122878
# 162265         -73.986525         40.740297                1  0.112210
# 162266         -74.006672         40.739620                1  1.875050
# 162267         -73.983215         40.695415                1  3.539715
# 162268         -73.985508         40.768793                1  5.417783
#
#         pickup_datetime_year  pickup_datetime_dayofmonth  \
# 0                       2015                           7
# 1                       2009                          17
# 2                       2009                          24
# 3                       2009                          26
# 4                       2011                          12
# ...                      ...                         ...
# 162264                  2014                          31
# 162265                  2012                          28
# 162266                  2014                          14
# 162267                  2015                          20
# 162268                  2010                          15
#
#         pickup_datetime_dayofweek  pickup_datetime_hour  \
# 0                               3                    19
# 1                               4                    20
# 2                               0                    21
# 3                               4                     8
# 4                               5                     2
# ...                           ...                   ...
# 162264                          4                    14
# 162265                          6                    10
# 162266                          4                     1
# 162267                          2                    14
# 162268                          5                     4
#
#        pickup_datetime_month_name
# 0                             May
# 1                            July
# 2                          August
# 3                            June
# 4                        February
# ...                           ...
# 162264                    January
# 162265                    October
# 162266                      March
# 162267                        May
# 162268                        May
#
# [162269 rows x 15 columns]
# c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\io\formats\style.py:3776: RuntimeWarning:
#
# invalid value encountered in longlong_scalars

# %%
#TODO : 
# Try to discover pattern on each day a week is weekday or sunday 
# try to discover pattern month 
#try to discover pattern in fare 
# try to discover busy hour (heatmap) extracting datetime
# try to discover density in area -> classify into dense / non dense area (try to look for a dynamic pricing paper)
#add holiday

# %%
data_eda.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'distance',
#        'pickup_datetime_year', 'pickup_datetime_dayofmonth',
#        'pickup_datetime_dayofweek', 'pickup_datetime_hour',
#        'pickup_datetime_month_name', 'pickup_datetime_weekday_name'],
#       dtype='object')

# %%
# Try to discover pattern on each day a week is weekday or sunday 
weekday_name = data_eda['pickup_datetime_weekday_name'].unique().tolist()
weekday_name_df = pd.DataFrame({f'{x}' : '' for x in weekday_name},index=)

# %%
weekday_name_df=pd.pivot_table(data_eda, columns=['pickup_datetime_weekday_name'], index=['pickup_datetime_month_name'], values='passenger_count', aggfunc='sum')
plt.figure(figsize=(12,8))
sns.heatmap(weekday_name_df, cmap ='RdYlGn', linewidths = 0.30)
# Out:
# <AxesSubplot:xlabel='pickup_datetime_weekday_name', ylabel='pickup_datetime_month_name'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
hour_day = pd.pivot_table(data_eda, columns=['pickup_datetime_hour'], index=['pickup_datetime_weekday_name'], values='passenger_count', aggfunc='sum')
plt.figure(figsize=(12,8))
sns.heatmap(hour_day, cmap ='RdYlGn', linewidths = 0.30)
# Out:
# <AxesSubplot:xlabel='pickup_datetime_hour', ylabel='pickup_datetime_weekday_name'>

# %%
data_eda
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         44470845    2011-02-12 02:27:09.0000006          4.9
# ...            ...                            ...          ...
# 162264     3189201  2014-01-31 14:42:00.000000181         12.0
# 162265    42598914   2012-10-28 10:49:00.00000053          3.0
# 162266    16382965    2014-03-14 01:09:00.0000008          7.5
# 162267    20259894    2015-05-20 14:56:25.0000004         14.5
# 162268    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                  pickup_datetime  pickup_longitude  pickup_latitude  \
# 0      2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1      2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2      2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3      2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4      2011-02-12 02:27:09+00:00        -73.969019        40.755910
# ...                          ...               ...              ...
# 162264 2014-01-31 14:42:00+00:00        -73.983070        40.760770
# 162265 2012-10-28 10:49:00+00:00        -73.987042        40.739367
# 162266 2014-03-14 01:09:00+00:00        -73.984722        40.736837
# 162267 2015-05-20 14:56:25+00:00        -73.997124        40.725452
# 162268 2010-05-15 04:08:00+00:00        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count  distance  \
# 0              -73.999512         40.723217                1  1.683323
# 1              -73.994710         40.750325                1  2.457590
# 2              -73.962565         40.772647                1  5.036377
# 3              -73.965316         40.803349                3  1.661683
# 4              -73.969019         40.755910                1  0.000000
# ...                   ...               ...              ...       ...
# 162264         -73.972972         40.754177                1  1.122878
# 162265         -73.986525         40.740297                1  0.112210
# 162266         -74.006672         40.739620                1  1.875050
# 162267         -73.983215         40.695415                1  3.539715
# 162268         -73.985508         40.768793                1  5.417783
#
#         pickup_datetime_year  pickup_datetime_dayofmonth  \
# 0                       2015                           7
# 1                       2009                          17
# 2                       2009                          24
# 3                       2009                          26
# 4                       2011                          12
# ...                      ...                         ...
# 162264                  2014                          31
# 162265                  2012                          28
# 162266                  2014                          14
# 162267                  2015                          20
# 162268                  2010                          15
#
#         pickup_datetime_dayofweek  pickup_datetime_hour  \
# 0                               3                    19
# 1                               4                    20
# 2                               0                    21
# 3                               4                     8
# 4                               5                     2
# ...                           ...                   ...
# 162264                          4                    14
# 162265                          6                    10
# 162266                          4                     1
# 162267                          2                    14
# 162268                          5                     4
#
#        pickup_datetime_month_name pickup_datetime_weekday_name
# 0                             May                     Thursday
# 1                            July                       Friday
# 2                          August                       Monday
# 3                            June                       Friday
# 4                        February                     Saturday
# ...                           ...                          ...
# 162264                    January                       Friday
# 162265                    October                       Sunday
# 162266                      March                       Friday
# 162267                        May                    Wednesday
# 162268                        May                     Saturday
#
# [162269 rows x 16 columns]

# %%
year_month = pd.pivot_table(data_eda, columns=['pickup_datetime_month_name'], index=['pickup_datetime_year'], values='passenger_count', aggfunc='sum')
plt.figure(figsize=(12,8))
sns.heatmap(year_month, cmap ='RdYlGn', linewidths = 0.30)
# Out:
# <AxesSubplot:xlabel='pickup_datetime_month_name', ylabel='pickup_datetime_year'>

# %%
data_eda
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         44470845    2011-02-12 02:27:09.0000006          4.9
# ...            ...                            ...          ...
# 162264     3189201  2014-01-31 14:42:00.000000181         12.0
# 162265    42598914   2012-10-28 10:49:00.00000053          3.0
# 162266    16382965    2014-03-14 01:09:00.0000008          7.5
# 162267    20259894    2015-05-20 14:56:25.0000004         14.5
# 162268    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                  pickup_datetime  pickup_longitude  pickup_latitude  \
# 0      2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1      2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2      2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3      2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4      2011-02-12 02:27:09+00:00        -73.969019        40.755910
# ...                          ...               ...              ...
# 162264 2014-01-31 14:42:00+00:00        -73.983070        40.760770
# 162265 2012-10-28 10:49:00+00:00        -73.987042        40.739367
# 162266 2014-03-14 01:09:00+00:00        -73.984722        40.736837
# 162267 2015-05-20 14:56:25+00:00        -73.997124        40.725452
# 162268 2010-05-15 04:08:00+00:00        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count  distance  \
# 0              -73.999512         40.723217                1  1.683323
# 1              -73.994710         40.750325                1  2.457590
# 2              -73.962565         40.772647                1  5.036377
# 3              -73.965316         40.803349                3  1.661683
# 4              -73.969019         40.755910                1  0.000000
# ...                   ...               ...              ...       ...
# 162264         -73.972972         40.754177                1  1.122878
# 162265         -73.986525         40.740297                1  0.112210
# 162266         -74.006672         40.739620                1  1.875050
# 162267         -73.983215         40.695415                1  3.539715
# 162268         -73.985508         40.768793                1  5.417783
#
#         pickup_datetime_year  pickup_datetime_dayofmonth  \
# 0                       2015                           7
# 1                       2009                          17
# 2                       2009                          24
# 3                       2009                          26
# 4                       2011                          12
# ...                      ...                         ...
# 162264                  2014                          31
# 162265                  2012                          28
# 162266                  2014                          14
# 162267                  2015                          20
# 162268                  2010                          15
#
#         pickup_datetime_dayofweek  pickup_datetime_hour  \
# 0                               3                    19
# 1                               4                    20
# 2                               0                    21
# 3                               4                     8
# 4                               5                     2
# ...                           ...                   ...
# 162264                          4                    14
# 162265                          6                    10
# 162266                          4                     1
# 162267                          2                    14
# 162268                          5                     4
#
#        pickup_datetime_month_name pickup_datetime_weekday_name
# 0                             May                     Thursday
# 1                            July                       Friday
# 2                          August                       Monday
# 3                            June                       Friday
# 4                        February                     Saturday
# ...                           ...                          ...
# 162264                    January                       Friday
# 162265                    October                       Sunday
# 162266                      March                       Friday
# 162267                        May                    Wednesday
# 162268                        May                     Saturday
#
# [162269 rows x 16 columns]

# %%
# !pip install geopy
# Out:
# Collecting geopy
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\djpb\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0

# %%
sample_data
# Out:
#    Unnamed: 0                          key  fare_amount  \
# 0    24238194  2015-05-07 19:52:06.0000003          7.5
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0 2015-05-07 19:52:06+00:00        -73.999817        40.738354
#
#    dropoff_longitude  dropoff_latitude  passenger_count  distance  \
# 0         -73.999512         40.723217                1  1.683323
#
#    pickup_datetime_year  pickup_datetime_dayofmonth  \
# 0                  2015                           7
#
#    pickup_datetime_dayofweek  pickup_datetime_hour pickup_datetime_month_name  \
# 0                          3                    19                        May
#
#   pickup_datetime_weekday_name
# 0                     Thursday

# %%
# Import module
from geopy.geocoders import Nominatim
 
# Initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")

sample_data = data_eda.iloc[:1]
# Out:
# None

# %%
data_eda.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'distance',
#        'pickup_datetime_year', 'pickup_datetime_dayofmonth',
#        'pickup_datetime_dayofweek', 'pickup_datetime_hour',
#        'pickup_datetime_month_name', 'pickup_datetime_weekday_name'],
#       dtype='object')

# %%
#add holidays into dataset 
import holidays

us_holidays = holidays.country_holidays('US')

# %%
us_holidays.items()
# Out:
# dict_items([])

# %%
#FEATURE ENGINEERING PHASE 
#1 Adding Holidays Feature 
def holiday_mapper(date) :
    if date in us_holidays_list : 
        holiday_name = us_holidays_dict.get(date)
        return [1], [holiday_name]
    else : 
        return [0], ['-']
    
data_eda.loc[:,['IsHoliday','Holiday']] = data_eda['pickup_datetime'].apply(lambda x :holiday_mapper(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\extension.py:158, in ExtensionIndex.map(self, mapper, na_action)
#     157 try:
# --> 158     result = mapper(self)
#     160     # Try to use this result if we can
#
# Input In [46], in <lambda>(x)
#       8         return [0], ['-']
# ---> 10 data_eda.loc[:,['IsHoliday','Holiday']] = data_eda['pickup_datetime'].apply(lambda x :holiday_mapper(x))
#
# Input In [46], in holiday_mapper(date)
#       3 def holiday_mapper(date) :
# ----> 4     if date in us_holidays_list :
#       5         holiday_name = us_holidays_dict.get(date)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\holidays\holiday_base.py:305, in HolidayBase.__contains__(self, key)
#     296 """Return true if date is in self, false otherwise. Accepts a date in
#     297 the following types:
#     298
#    (...)
#     303 * or a :class:`float` or :class:`int` representing a POSIX timestamp.
#     304 """
# --> 305 return dict.__contains__(self, self.__keytransform__(key))
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\holidays\holiday_base.py:286, in HolidayBase.__keytransform__(self, key)
#     285 else:
# --> 286     raise TypeError("Cannot convert type '%s' to date." % type(key))
#     288 if self.expand and out_key.year not in self.years:
#
# TypeError: Cannot convert type '<class 'pandas.core.indexes.datetimes.DatetimeIndex'>' to date.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\categorical.py:438, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     437 try:
# --> 438     codes, categories = factorize(values, sort=True)
#     439 except TypeError as err:
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py:763, in factorize(values, sort, na_sentinel, size_hint)
#     761         na_value = None
# --> 763     codes, uniques = factorize_array(
#     764         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     765     )
#     767 if sort and len(uniques) > 0:
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py:560, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     559 table = hash_klass(size_hint or len(values))
# --> 560 uniques, codes = table.factorize(
#     561     values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     562 )
#     564 codes = ensure_platform_int(codes)
#
# File pandas\_libs\hashtable_class_helper.pxi:5394, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 10>()
#       7     else :
#       8         return [0], ['-']
# ---> 10 data_eda.loc[:,['IsHoliday','Holiday']] = data_eda['pickup_datetime'].apply(lambda x :holiday_mapper(x))
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:1129, in SeriesApply.apply_standard(self)
#    1126 # row-wise access
#    1127 if is_extension_array_dtype(obj.dtype) and hasattr(obj._values, "map"):
#    1128     # GH#23179 some EAs do not have `map`
# -> 1129     mapped = obj._values.map(f)
#    1130 else:
#    1131     values = obj.astype(object)._values
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\_mixins.py:84, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      81 @wraps(meth)
#      82 def method(self, *args, **kwargs):
#      83     if self.ndim == 1:
# ---> 84         return meth(self, *args, **kwargs)
#      86     flags = self._ndarray.flags
#      87     flat = self.ravel("K")
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimelike.py:775, in DatetimeLikeArrayMixin.map(self, mapper)
#     766 @ravel_compat
#     767 def map(self, mapper):
#     768     # TODO(GH-23179): Add ExtensionArray.map
#    (...)
#     771     # a standalone function and call from here..
#     772     # Else, just rewrite _map_infer_values to do the right thing.
#     773     from pandas import Index
# --> 775     return Index(self).map(mapper).array
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\extension.py:168, in ExtensionIndex.map(self, mapper, na_action)
#     166     return result
#     167 except Exception:
# --> 168     return self.astype(object).map(mapper)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py:6086, in Index.map(self, mapper, na_action)
#    6084     else:
#    6085         names = None
# -> 6086     return MultiIndex.from_tuples(new_values, names=names)
#    6088 dtype = None
#    6089 if not new_values.size:
#    6090     # empty
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\multi.py:204, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     201 elif "name" in kwargs:
#     202     kwargs["names"] = kwargs.pop("name")
# --> 204 return meth(self_or_cls, *args, **kwargs)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\multi.py:566, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     563     arrs = zip(*tuples)
#     564     arrays = cast(List[Sequence[Hashable]], arrs)
# --> 566 return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\multi.py:489, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     486     if len(arrays[i]) != len(arrays[i - 1]):
#     487         raise ValueError("all arrays must be same length")
# --> 489 codes, levels = factorize_from_iterables(arrays)
#     490 if names is lib.no_default:
#     491     names = [getattr(arr, "name", None) for arr in arrays]
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\categorical.py:2881, in factorize_from_iterables(iterables)
#    2877 if len(iterables) == 0:
#    2878     # For consistency, it should return two empty lists.
#    2879     return [], []
# -> 2881 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2882 return list(codes), list(categories)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\categorical.py:2881, in <genexpr>(.0)
#    2877 if len(iterables) == 0:
#    2878     # For consistency, it should return two empty lists.
#    2879     return [], []
# -> 2881 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2882 return list(codes), list(categories)
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\categorical.py:2854, in factorize_from_iterable(values)
#    2849     codes = values.codes
#    2850 else:
#    2851     # The value of ordered is irrelevant since we don't use cat as such,
#    2852     # but only the resulting categories, the order of which is independent
#    2853     # from ordered. Set ordered to False as default. See GH #15457
# -> 2854     cat = Categorical(values, ordered=False)
#    2855     categories = cat.categories
#    2856     codes = cat.codes
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\categorical.py:440, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     438     codes, categories = factorize(values, sort=True)
#     439 except TypeError as err:
# --> 440     codes, categories = factorize(values, sort=False)
#     441     if dtype.ordered:
#     442         # raise, as we don't have a sortable data structure and so
#     443         # the user should give us one by specifying categories
#     444         raise TypeError(
#     445             "'values' is not ordered, please "
#     446             "explicitly specify the categories order "
#     447             "by passing in a categories argument."
#     448         ) from err
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py:763, in factorize(values, sort, na_sentinel, size_hint)
#     760     else:
#     761         na_value = None
# --> 763     codes, uniques = factorize_array(
#     764         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     765     )
#     767 if sort and len(uniques) > 0:
#     768     uniques, codes = safe_sort(
#     769         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     770     )
#
# File c:\users\djpb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\algorithms.py:560, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     557 hash_klass, values = _get_data_algo(values)
#     559 table = hash_klass(size_hint or len(values))
# --> 560 uniques, codes = table.factorize(
#     561     values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     562 )
#     564 codes = ensure_platform_int(codes)
#     565 return codes, uniques
#
# File pandas\_libs\hashtable_class_helper.pxi:5394, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
